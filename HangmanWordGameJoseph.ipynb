# %% [markdown]
# <a href="https://colab.research.google.com/github/Joseph-KB/Rubix/blob/main/HangmanWordGameJoseph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If you are using Google chrome in mobile phone you should change it into desktop site mode.
# Advice to use Computer(PC,Laptop)
#
#
# 1.   1st you should click on the play button inside the square bracket below "Below is the program of the game" on left side
#
# 2.   Next You should click on the play button below"To play hungman click on the run button". on the left
# 3. Then you should enter your answers or selection only in the box popping up..

# %% [markdown]
# #Below is the Program of the game

# %%
 
 
 
 
 
def rungame():
########################################## import libraries
 
 
    import random
    import time
 
############################ An initial list is Created
 
    Words=["Apple","ball","CAT","Dog","elephant","Fan","Girraf","Human"]
 
 
 
############################ Function to append more words is created
    def addmore(further):
        if further == 1:
            word=input("Enter the word to enter \n")
            Words.append(word)
        
            print()
            choose=input("If you want to add more word press 1 else press 0 to play the GamE:   ")
            choose=int(choose)
            if choose==1:
              addmore(choose)
            elif choose == 0:
                print()
                print("+++++++++++++++++++")
                print("Lets Play The Game Hangman... Beware that your Man will be hanged if you MiSsSpeLlS.. (* - *) ")
                print("+++++++++++++++++++")
                print()
            else:
                addmore(choose)
 
        elif further == 0:
            print()
            print("+++++++++++++++++++")
            print("Lets Play The Game Hangman... Beware that your Man will be hanged if you MiSsSpeLlS.. (* - *)")
            print("+++++++++++++++++++")
            print()
        else:
            print("Wrong input")
            print()
            choose2=input("If you want to add more word press 1 else press 0 to play the GamE:   ")
            choose2=int(choose2)
            if choose2==1:
              addmore(choose2)
            elif choose2 == 0:
                print()
                print("+++++++++++++++++++")
                print("Lets Play The Game Hangman... Beware that your Man will be hanged if you MiSsSpeLlS.. (* - *)")
                print("+++++++++++++++++++")
                print()
                pass
            else:
                addmore(choose2)
 
 
 
########################################## Welcome note and append word authorisation
 
    print()
    print()
    title="Welcome To Hangman Word Puzzle"
    print("**********************{0:^30}********************** \n".format(title))
    print()
    print()
    initial=input("If you want to add more word press 1 else press 0 to play the GamE:   ")
    initial=int(initial)
    print()
    print()
    if initial==1:
        username=input("Enter your user name(case sensitive):  ")
        password=input("Enter your password(case sensitive):   ")
        if username=="joseph" and password=="Joseph1234":
            print()
            further=input("Press 1 if you need to add more words to Hangman Dictionary else press 0 to proceed to the GamE:   ")
            further=int(further)
 
            addmore(further)
        else:
            print()
            print()
            print("xxxxxxxxxxxxxxxxMISMATCH FOUND you cant add words \nxxxxxxxxxxxxxxxxxxx")
    elif initial==0:
        print()
        print("+++++++++++++++++++")
        print("Lets Play The Game Hangman... Beware that your Man will be hanged if you MiSsSpeLlS.. (* - *)  ")
        print("+++++++++++++++++++")
        print()
    else:
        print("Wrong input in selection. System Crashed Start Playing the game")
        print()
        print("+++++++++++++++++++")
        print("Lets Play The Game Hangman... Beware that your Man will be hanged if you MiSsSpeLlS.. (* - *)  ")
        print("+++++++++++++++++++")
        print()
 
######################### All strings in list is converted to lower case
 
    Wordlist=[]
 
    for x in Words:
        y=x.lower()
        Wordlist.append(y)
    print("List of words you have is:  ",end=' ')
    print(Wordlist)
    print()
 
############################### Select random string from list
 
 
    answer = random.choice(Wordlist)
    answerlis=list(answer)
##   print(answer)
 
    a=""
    for i in answer:
        a+="_ "
 
    print("Length of the word is  ",(len(a)//2))
    print("Fill the blank with correct word: ",a)
    print()
 
    temp=[]
    x='_'
    for j in range(0,len(answer)):
      temp.append(x)
    temp1=" ".join(temp)
    temp2=temp
 
    print()
 
 
 
#######################################  Function to loop  through letters is created
 
    def loopletters():
        hangman()
        x=input("Enter your letter ------->> ")
        x=x.lower()
        count=answer.count(x)
        find=answer.find(x)
 
 
    
        if count==1:
            temp2[find]=answerlis[find]
            print(" ".join(temp2))
            print()
            print("You are left with ",(-1*(len(balance)-n1)),"chances.")
            print()
            
        if count>1:
            n=len(answer)
            m=0
            for i in range(m,(len(answer))):
                if x == answer[i]:
                    temp2[m]=answerlis[m] 
                n-=1
                m+=1
            print(" ".join(temp2))
            print()
            print("You are left with ",(-1*(len(balance)-n1)),"chances.")
            print()
            print()
            
 
        if x not in answerlis:
            balance.append("W")
            print(" ".join(temp2))
            print()
            print("You are left with ",(n1-len(balance)),"chances.")
            print()
            print()
            print("Wrong === MissSpleed")
            print("Be care full you are only left with ",(-1*(len(balance)-n1)),"chances only.")
            print()
            
 
####################Function to call print man
    def hangman():
        if n1-len(balance)==4:
            print("            ___________      ")
            print("           |           |     ")
            print("           |           |     ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
        if n1-len(balance)==3:
            print("            ___________      ")
            print("           |           |     ")
            print("           |           |     ")
            print("           |                 ")
            print("           |          /`\      ")
            print("           |         (*.*)  ")
            print("           |          \~/     ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
            print("           |                 ")
        if n1-len(balance)==2:
            print("            ___________     ")
            print("           |           |    ")
            print("           |           |    ")
            print("           |                ")
            print("           |          /`\      ")
            print("           |         (*.*)  ")
            print("           |          \~/     ")
            print("           |           |    ")
            print("           |           |    ")
            print("           |           |    ")
            print("           |           |  ")
            print("           |              ")
            print("           |              ")
        if n1-len(balance)==1:
            print("            ___________     ")
            print("           |           |    ")
            print("           |           |    ")
            print("           |                ")
            print("           |          /`\      ")
            print("           |         (*.*)  ")
            print("           |          \~/     ")
            print("           |         __|__  ")
            print("           |        |  |  | ")
            print("           |        |  |  | ")
            print("           |           |    ")
            print("           |                ")
            print("           |                ")            
 
        if n1-len(balance)==0:
            print("Hanged")
            print("            ___________     ")
            print("           |           |    ")
            print("           |           |    ")
            print("           |                ")
            print("           |         (X  X)  ")
            print("           |         __|__  ")
            print("           |        |  |  | ")
            print("           |        |  |  | ")
            print("           |         __|__  ")
            print("           |        |     | ")
            print("           |        |     | ")
 
 
############## Functions are called using loops
    balance=[]
    n1=4            ##### Set number of chances here
    while temp2!=answerlis:
        loopletters()
        print("__________________________________________________________")
    
        if len(balance)==4:  ### Se number of chances here
            print()
            print("Your chance limit exceded....")
            print("Loading.......")
            print("......... \n")
            time.sleep(4)
            print("Your answer missmatched.\nThe answer was: ",(answer.upper()))
            print()
            hangman()
            print()
            print("******************Your Man is Hanged.********************Game Ends****************")
            print()
 
            break
    if temp2==answerlis:
        print()
        print()
        print("Loading..........")
        print("......... \n")
        time.sleep(4)
        print("Your answer matched.")
        print("The answer is:  ",(answer.upper()))
        print()
        hangman()
        print()
        print("******************Your Saved Your Man. Your are a man of word.********************Game Ends****************")
 
 
 
################################## Game over text
    print()
    print()
    print("----------------------{0:^20}------------------------".format("GaMe OvEr"))
    print()
    print()

# %% [markdown]
# #To play HangMan click on the run button

# %%
rungame()
# Out:
# **********************Welcome To Hangman Word Puzzle**********************
#
#
#
# If you want to add more word press 1 else press 0 to play the GamE:   0
#
#
#
# +++++++++++++++++++
# Lets Play The Game Hangman... Beware that your Man will be hanged if you MiSsSpeLlS.. (* - *)
# +++++++++++++++++++
#
# List of words you have is:   ['apple', 'ball', 'cat', 'dog', 'elephant', 'fan', 'girraf', 'human']
#
# Length of the word is   3
# Fill the blank with correct word:  _ _ _
#
#
#             ___________
#            |           |
#            |           |
#            |
#            |
#            |
#            |
#            |
#            |
#            |
#            |
# Enter your letter ------->> Z
# _ _ _
#
# You are left with  3 chances.
#
#
# Wrong === MissSpleed
# Be care full you are only left with  3 chances only.
#
# __________________________________________________________
#             ___________
#            |           |
#            |           |
#            |
# ...
